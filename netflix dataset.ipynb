# %%
import numpy as np
import pandas as pd
netfilx=pd.read_csv('data_netflix.csv')
netfilx
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
#------head - it will display first 5 lines of  data
#------tail - it will display last 5 lines of data

# %%
netfilx.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
netfilx.tail(10)
# Out:
#        show_id     type                                        title director  \
# 6224  70304979  TV Show              Anthony Bourdain: Parts Unknown      NaN
# 6225  70153412  TV Show                                      Frasier      NaN
# 6226  70243132  TV Show                          La Familia P. Luche      NaN
# 6227  80005756  TV Show                 The Adventures of Figaro Pho      NaN
# 6228  80159925  TV Show                                     Kikoriki      NaN
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
#                                                    cast         country  \
# ...

# %%
netfilx.head(150)
# Out:
#       show_id     type                                    title  \
# 0    81145628    Movie  Norm of the North: King Sized Adventure
# 1    80117401    Movie               Jandino: Whatever it Takes
# 2    70234439  TV Show                       Transformers Prime
# 3    80058654  TV Show         Transformers: Robots in Disguise
# 4    80125979    Movie                             #realityhigh
# ..        ...      ...                                      ...
# 145  81172728    Movie   The Wedding Party 2: Destination Dubai
# 146  81095101  TV Show                                 Vagabond
# 147  80195173  TV Show                               Battlefish
# 148  80241960  TV Show           DRAGON PILOT: Hisone & Masotan
# 149  80115346  TV Show                                    Hilda
#
#                      director  \
# 0    Richard Finn, Tim Maltby
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4            Fernando Lebrija
# ...

# %%
netfilx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
netfilx.index
# Out:
# RangeIndex(start=0, stop=6234, step=1)

# %%
netfilx.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netfilx.loc[1226]
# Out:
# show_id                                                  81073633
# type                                                        Movie
# title                                  Iliza Shlesinger: Unveiled
# director                                              Steve Paley
# cast                                             Iliza Shlesinger
# country                                             United States
# date_added                                      November 19, 2019
# release_year                                                 2019
# rating                                                      TV-MA
# duration                                                   78 min
# listed_in                                         Stand-Up Comedy
# description     Here comes the bride, and she's got plenty to ...
# Name: 1226, dtype: object

# %%
netfilx['release_year'].min()
# Out:
# 1925

# %%
netfilx[netfilx['release_year'] == 2019]
# Out:
#        show_id     type                                    title  \
# 0     81145628    Movie  Norm of the North: King Sized Adventure
# 34    80221550  TV Show               Archibald's Next Big Thing
# 35    81154455    Movie                               Article 15
# 38    81132437    Movie                      Kill Me If You Dare
# 39    80178151  TV Show                                  The Spy
# ...        ...      ...                                      ...
# 6198  80189829  TV Show                            The Protector
# 6204  80091341  TV Show                                   Cuckoo
# 6206  80173174  TV Show                                Samantha!
# 6215  80066227  TV Show                      Crazy Ex-Girlfriend
# 6219  80186475  TV Show                       Pokémon the Series
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 34                         NaN
# 35               Anubhav Sinha
# 38                Şenol Sönmez
# ...

# %%
netfilx[netfilx['release_year'] == 2003]
# Out:
#        show_id     type                                              title  \
# 311   60031232    Movie                                       Mystic River
# 372   70036200    Movie  Inuyasha the Movie - La spada del dominatore d...
# 782   60029167    Movie                                        Bad Boys II
# 786   60027726    Movie                    Charlie's Angels: Full Throttle
# 791   60027716    Movie            Dumb and Dumberer: When Harry Met Lloyd
# 1263  81179844  TV Show                                 At the Dolphin Bay
# 1282  81179864  TV Show                                     Westside Story
# 1350  60027583    Movie                                   Anger Management
# 1373  60031247    Movie                                            Gothika
# 1423  60027695    Movie                                The Matrix Reloaded
# 1424  60031303    Movie                             The Matrix Revolutions
# ...

# %%
size=len(netfilx['title'])
size
# Out:
# 6234

# %%
#drop -- going to remove the particular column
netfilx.drop('director',axis=1)
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                                                    cast  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# ...

# %%
netfilx.describe()
# Out:
#             show_id  release_year
# count  6.234000e+03    6234.00000
# mean   7.670368e+07    2013.35932
# std    1.094296e+07       8.81162
# min    2.477470e+05    1925.00000
# 25%    8.003580e+07    2013.00000
# 50%    8.016337e+07    2016.00000
# 75%    8.024489e+07    2018.00000
# max    8.123573e+07    2020.00000

# %%
netfilx.shape
# Out:
# (6234, 12)

# %%
netfilx.duplicated().sum()
# Out:
# np.int64(0)

# %%
netfilx.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
netfilx[['title','listed_in','duration']]
# Out:
#                                             title  \
# 0         Norm of the North: King Sized Adventure
# 1                      Jandino: Whatever it Takes
# 2                              Transformers Prime
# 3                Transformers: Robots in Disguise
# 4                                    #realityhigh
# ...                                           ...
# 6229                                 Red vs. Blue
# 6230                                        Maron
# 6231       Little Baby Bum: Nursery Rhyme Friends
# 6232  A Young Doctor's Notebook and Other Stories
# 6233                                      Friends
#
#                                               listed_in    duration
# 0                    Children & Family Movies, Comedies      90 min
# 1                                       Stand-Up Comedy      94 min
# 2                                              Kids' TV    1 Season
# 3                                              Kids' TV    1 Season
# ...

# %%
# IMDB   -- Internet movie database
import numpy as np
IMDB =np.random.uniform(low=0,high=10,size=len(netfilx['title']))
IMDB=np.around(IMDB,decimals=2)
# adding the 'IMDB rating' column as a new column
netfilx['IMDB rating']=IMDB
netfilx
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
netfilx[netfilx.isnull().any(axis=1)]
# Out:
#        show_id     type                                        title director  \
# 1     80117401    Movie                   Jandino: Whatever it Takes      NaN
# 2     70234439  TV Show                           Transformers Prime      NaN
# 3     80058654  TV Show             Transformers: Robots in Disguise      NaN
# 5     80163890  TV Show                                      Apaches      NaN
# 8     80117902  TV Show                                 Fire Chasers      NaN
# ...        ...      ...                                          ...      ...
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
# ...

# %%
# drop item which have missing values in any of the column
netfilx.dropna()
# Out:
#        show_id     type                                    title  \
# 0     81145628    Movie  Norm of the North: King Sized Adventure
# 4     80125979    Movie                             #realityhigh
# 6     70304989    Movie                                 Automata
# 7     80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 9     70304990    Movie                              Good People
# ...        ...      ...                                      ...
# 6142  80063224  TV Show            The Great British Baking Show
# 6158  80164216  TV Show  Miraculous: Tales of Ladybug & Cat Noir
# 6167  80115328  TV Show                             Sacred Games
# 6182  80176842  TV Show                         Men on a Mission
# 6213  80126599  TV Show                         Leyla and Mecnun
#
#                                   director  \
# 0                 Richard Finn, Tim Maltby
# 4                         Fernando Lebrija
# 6                              Gabe Ibáñez
# ...

# %%
netfilx.replace({'country':{'United States':'US','United Kingdom':'UK'}})
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
 z# get max min and mean of the 'IMDBB rating' using agg()
netfilx['IMDB rating'].agg(['max','min','mean'])
# Out:
# max     10.000000
# min      0.000000
# mean     4.992892
# Name: IMDB rating, dtype: float64

# %%
netfilx[netfilx['IMDB rating']==6]
# Out:
#        show_id     type                                title  \
# 566   15815343    Movie          The Texas Chainsaw Massacre
# 884   80187618    Movie                         Manje Bistre
# 2199  80226021    Movie  Jag älskar dig: En skilsmässokomedi
# 2491  80190144    Movie               The House on Coco Road
# 2983  80081277    Movie                              Colonia
# 3764  81044300  TV Show             The Last of the Schmucks
# 4323  80244708    Movie                    When Angels Sleep
# 4501  70001237    Movie                              Lakshya
#
#                                                    cast  \
# 566   Gunnar Hansen, Jim Siedow, Marilyn Burns, Edwi...
# 884   Gippy Grewal, Sonam Bajwa, Karamjit Anmol, Jag...
# 2199  Björn Kjellman, Christine Meltzer, Rodolfo Cor...
# 2491                                                NaN
# 2983  Emma Watson, Daniel Brühl, Michael Nyqvist, Ri...
# 3764  Chico, Ahmed Mekky, Hesham Maged, Bayoumi Foua...
# ...
