# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import plotly.offline as py

# %%
data=pd.read_csv('alldata.csv')
data
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# ...

# %%
data.head()
# Out:
#                                             position             company  \
# 0                               Development Director             ALS TDI
# 1  An Ostentatiously-Excitable Principal Research...  The Hexagon Lavish
# 2                                     Data Scientist      Xpert Staffing
# 3                                       Data Analyst      Operation HOPE
# 4  Assistant Professor -TT - Signal Processing & ...    Emory University
#
#                                          description  reviews  \
# 0  Development Director\nALS Therapy Development ...      NaN
# 1  Job Description\n\n"The road that leads to acc...      NaN
# 2  Growing company located in the Atlanta, GA are...      NaN
# 3  DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0
# 4  DESCRIPTION\nThe Emory University Department o...    550.0
#
#              location
# 0  Atlanta, GA 30301
# 1         Atlanta, GA
# 2         Atlanta, GA
# 3  Atlanta, GA 30303
# 4         Atlanta, GA

# %%
pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport

# %%
data.describe(include='all')
# Out:
#               position     company  \
# count             6953        6953
# unique            5242        2213
# top     Data Scientist  Amazon.com
# freq               351         358
# mean               NaN         NaN
# std                NaN         NaN
# min                NaN         NaN
# 25%                NaN         NaN
# 50%                NaN         NaN
# 75%                NaN         NaN
# max                NaN         NaN
#
#                                               description        reviews  \
# count                                                6953    5326.000000
# unique                                               6702            NaN
# top     Note: By applying to this position your applic...            NaN
# freq                                                    9            NaN
# mean                                                  NaN    3179.089185
# std                                                   NaN    8448.515056
# ...

# %%
#all the values seem to be catagorical
ProfileReport(data)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.18.1&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-04-10 04:33:15.568767&quot; name=date&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
dataset=data.copy()

# %%
dataset.dropna(inplace=True)
dataset['reviews'].fillna(0,inplace=True)
# Out:
# /tmp/ipykernel_11499/1875081443.py:2: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
dataset
# Out:
#                                                position  \
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# 5                           Manager of Data Engineering
# 6          Product Specialist - Periscope, New Ventures
# 7     Junior to Mid-level Engineer, Geologist or Env...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 3                       Operation HOPE
# 4                     Emory University
# 5                   McKinsey & Company
# 6                   McKinsey & Company
# 7                                 Wood
# ...                                ...
# ...

# %%
data
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5326 entries, 3 to 6963
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     5326 non-null   object
#  1   company      5326 non-null   object
#  2   description  5326 non-null   object
#  3   reviews      5326 non-null   float64
#  4   location     5326 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 249.7+ KB

# %%
#finding the top 40 companies which has open positions
from matplotlib.pyplot import figure,show
import matplotlib.pyplot as plt
import seaborn as sns
fig,a=plt.subplots(figsize=(10,6))
sns.barplot(data=dataset.groupby('company').count().nlargest(40,'position').reset_index(),x='company',y='position')
a.set_xticklabels(dataset.groupby('company').count().nlargest(40, 'position').reset_index()['company'],rotation=90)
a.set_ylabel('No Of Positions',fontsize=16,color='red')
a.set_xlabel('Company Name',fontsize=16,color='red')
# Out:
# /tmp/ipykernel_11499/890417942.py:7: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# Text(0.5, 0, 'Company Name')

# %%
# Grouping logic-ah easy-ah mudinga
top_40_data = dataset.groupby('company')['position'].count().nlargest(40).reset_index()

plt.figure(figsize=(12, 6))

# Plotting using Seaborn
plot = sns.barplot(data=top_40_data, x='company', y='position', palette='viridis')

# Aesthetics
plt.xticks(rotation=90)
plt.ylabel('No Of Positions', fontsize=12, color='red')
plt.xlabel('Company Name', fontsize=12, color='red')
plt.title('Top 40 Companies with Open Positions', fontsize=14)

plt.show()
# Out:
# /tmp/ipykernel_11499/2135417954.py:7: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# finding the top 40 designtion which are in high demand

# %%
from matplotlib.pyplot import figure, show
import matplotlib.pyplot as plt
fig,a=plt.subplots(figsize=(10,6))
sns.barplot(data=dataset.groupby('position').count().nlargest(40, 'company').reset_index(), x ='position', y='company')
a.set_xticklabels(dataset.groupby('position').count().nlargest(40, 'company').reset_index()['position'],rotation=90)
a.set_ylabel('Count',fontsize=16,color='red')
a.set_xlabel('Designation',fontsize=16,color='red')
# Out:
# /tmp/ipykernel_11499/3770615015.py:5: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# Text(0.5, 0, 'Designation')

# %% [markdown]
#    DESIGNATION

# %%
## Grouping the designations into the following roles
## Data Scientist, Lead Data Scientist, Data Engineer, Data Analyst, Director

## Filtered all the directors from the table
dataset.loc[dataset['position'].str.contains('Director', case=False) & dataset['position'].str.contains('data', case=False), 'designation'] = 'Director'

# %%
#drop all the designations that are not related to Data Science as we areperforming EDA only on Data science roles
dataset['designation'].dropna(inplace=True)
#drop all null rows
dataset.dropna(inplace=True)

# %%
dataset.head()
# Out:
#                                               position            company  \
# 51                            Director, Data Scientist               KPMG
# 71                        Director, NLP Data Scientist               KPMG
# 81                            Director of Data Science  Prestige Staffing
# 88       Director, Financial Services - Data Scientist               KPMG
# 111  Director, Data Scientist -- Financial Services...               KPMG
#
#                                            description  reviews  \
# 51   Innovate. Collaborate. Shine. Lighthouse — KPM...   4494.0
# 71   Innovate. Collaborate. Shine. Lighthouse — KPM...   4494.0
# 81   Director of Data ScienceSkills:  Leadership, D...    139.0
# 88   Innovate. Collaborate. Shine. Lighthouse — KPM...   4494.0
# 111  Innovate. Collaborate. Shine. Lighthouse — KPM...   4494.0
#
#               location designation
# 51   Atlanta, GA 30338    Director
# 71   Atlanta, GA 30338    Director
# ...

# %%
dataset['location'].value_counts().head(50)
# Out:
# location
# San Francisco, CA          11
# New York, NY                8
# Chicago, IL                 5
# Atlanta, GA 30338           4
# Seattle, WA 98104           4
# New York, NY 10041          3
# New York, NY 10154          3
# Washington, DC 20036        2
# Chicago, IL 60654           2
# San Diego, CA               2
# Atlanta, GA                 2
# Chicago, IL 60601           2
# Boston, MA                  2
# Round Rock, TX              1
# Austin, TX                  1
# New York, NY 10261          1
# Mountain View, CA 94039     1
# Los Angeles, CA             1
# Boston, MA 02110            1
# Atlanta, GA 30301           1
# Austin, TX 78759            1
# New York, NY 10104          1
# New York, NY 10154          1
# Jersey City, NJ 07310       1
# New York, NY 10013          1
# New York, NY 10176          1
# Manhattan, NY               1
# San Francisco, CA 94158     1
# San Francisco, CA 94105     1
# San Francisco, CA 94103     1
# ...

# %%
# How the jobs are distributed geographically?
from matplotlib.pyplot import figure, show
width=18
height=6
figure(figsize=(width,height))
#sns.barplot(data=ds_df.groupby(['location'])['position'].count().reset_index(), x='location', y='position')
sns.countplot(data=dataset, x='location')
show()

# %%
# Based on the previous graph we have only figured out total open positions at every location
# It would be more intuitive if we know different designated open positions at each location, let us plot that.
#This can be achieved by adding hue paramter to the above graph plot
from matplotlib.pyplot import figure, show
width=18
height=6
figure(figsize=(width,height))
sns.countplot(data=dataset, x='location',hue='designation')
show()

# %%
top_20_company_list = dataset.groupby(['company'])['location'].count().reset_index().sort_values('location',ascending=False).head(20)['company'].tolist()
# Based on the previous graph we have only figured out total open positions at every location
# It would be more intuitive if we know different designated open positions at each location, let us plot that.
# It can be achieved by adding hue to the above countplot
from matplotlib.pyplot import figure, show
import matplotlib.pyplot as plt
fig,a=plt.subplots(figsize=(18,10))
ax = sns.countplot(data=dataset[dataset['company'].isin(top_20_company_list)], x='company',hue='designation')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_11499/4142012598.py:9: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
df_final =  pd.DataFrame(dataset.groupby(['company','location','designation'])['position'].count().reset_index())

# for company KPMG how are the postions at different location distributed with designation
from matplotlib.pyplot import figure, show
import matplotlib.pyplot as plt
fig,a=plt.subplots(figsize=(3,3))
ax = sns.countplot(data=df_final[df_final['company'] == 'KPMG'], x='location',hue='designation')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_11499/1478322554.py:8: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
